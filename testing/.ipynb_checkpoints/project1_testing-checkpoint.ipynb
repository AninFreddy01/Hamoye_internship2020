# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
df = pd.read_csv('fuel_ferc1.csv')

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
df.shape
# Out:
# (29523, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
df.dtypes
# Out:
# record_id                        object
# utility_id_ferc1                  int64
# report_year                       int64
# plant_name_ferc1                 object
# fuel_type_code_pudl              object
# fuel_unit                        object
# fuel_qty_burned                 float64
# fuel_mmbtu_per_unit             float64
# fuel_cost_per_unit_burned       float64
# fuel_cost_per_unit_delivered    float64
# fuel_cost_per_mmbtu             float64
# dtype: object

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
df['fuel_unit'].unique()
# Out:
# array(['ton', 'mcf', 'kgU', 'bbl', 'gramsU', nan, 'mwdth', 'mmbtu',
#        'mwhth', 'gal'], dtype=object)

# %%
df.duplicated().any()
# Out:
# False

# %%
df['fuel_type_code_pudl'].unique()
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'waste', 'other'], dtype=object)

# %%
df[df['fuel_type_code_pudl'] == 'other']
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 84       f1_fuel_1994_12_11_0_6                11         1994
# 203      f1_fuel_1994_12_54_0_6                54         1994
# 228      f1_fuel_1994_12_61_0_9                61         1994
# 277      f1_fuel_1994_12_74_0_3                74         1994
# 349      f1_fuel_1994_12_99_0_1                99         1994
# ...                         ...               ...          ...
# 23961   f1_fuel_2013_12_98_0_13                98         2013
# 24011  f1_fuel_2013_12_195_2_15               195         2013
# 25040   f1_fuel_2014_12_98_0_13                98         2014
# 25831   f1_fuel_2015_12_98_0_13                98         2015
# 27065   f1_fuel_2016_12_98_0_13                98         2016
#
#         plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 84            w.f. wyman               other       bbl          55652.0
# ...

# %%
df.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df['fuel_type_code_pudl'].value_counts().plot()
plt.xlabel('Fuel Type', fontsize = 15)
plt.ylabel('Quantity', fontsize = 15)
# Out:
# Text(0, 0.5, 'Quantity')

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1.tail()
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 28413  f1_fuel_2017_12_227_0_13               227         2017
# 28828  f1_fuel_2018_12_148_0_12               148         2018
# 28830  f1_fuel_2018_12_148_0_14               148         2018
# 29052   f1_fuel_2018_12_162_0_1               162         2018
# 29053   f1_fuel_2018_12_162_0_4               162         2018
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 28413         vestaburg                 gas       NaN          24196.0
# 28828    northeastern 3                 oil       NaN             11.0
# 28830          comanche                 oil       NaN             96.0
# 29052  ernest c. gaston                coal       NaN        1610370.0
# 29053  ernest c. gaston                 oil       NaN            688.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 28413             1.000000                     20.131
# ...

# %%
data = df.dropna(axis=0)

# %%
data.shape
# Out:
# (29343, 11)

# %%
data.isna().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
df['report_year'].value_counts().plot(kind='bar')

# %%
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
data.groupby(['plant_name_ferc1']).agg({'plant_name_ferc1':'count','fuel_cost_per_mmbtu':'sum'})
# Out:
#                      plant_name_ferc1  fuel_cost_per_mmbtu
# plant_name_ferc1
# (1)sta98                            1               3.3990
# (2) scriba sta. 99                  1               0.4990
# (n) contra costa                    1               2.1100
# (n) pittsburg                       1               2.1800
# (n)(t)moss landing                  1               2.2200
# ...                               ...                  ...
# zimmer- aepgr share                 2              25.3670
# zion                                3               1.4440
# zorn                               12              51.6810
# zorn ct                            10              55.6880
# zuni                               16              92.9213
#
# [2307 rows x 2 columns]

# %%
sns.distplot(df['fuel_type_code_pudl'].value_counts(), df['report_year'])

# %%
data.groupby(['fuel_type_code_pudl']).agg({'fuel_cost_per_mmbtu':'sum','fuel_type_code_pudl':'count'})
# Out:
#                      fuel_cost_per_mmbtu  fuel_type_code_pudl
# fuel_type_code_pudl
# coal                         15183.58317                 8496
# gas                          61862.05698                11433
# nuclear                       1398.65500                  803
# oil                         102077.20162                 8043
# other                          801.48000                  131
# waste                       362812.87600                  437

# %%
pd.crosstab(data['fuel_type_code_pudl'], data['report_year'], margins=True)
# Out:
# report_year          1994  1995  1996  1997  1998  1999  2000  2001  2002  \
# fuel_type_code_pudl
# coal                  469   463   426   417   428   424   402   360   329
# gas                   480   500   424   447   514   490   472   448   439
# nuclear                65    73    41    31    56    56    55    43    33
# oil                   164   113   160   163    68    48   416   474   374
# other                  11    14     8    12    14    10     9     5     5
# waste                  24    21    21    21    20    14    14    15    15
# All                  1213  1184  1080  1091  1100  1042  1368  1345  1195
#
# report_year          2003  ...  2010  2011  2012  2013  2014  2015  2016  \
# fuel_type_code_pudl        ...
# coal                  328  ...   315   322   326   319   294   267   236
# gas                   401  ...   494   488   481   469   468   468   465
# nuclear                29  ...    20    22    21    20    20    21    19
# ...
